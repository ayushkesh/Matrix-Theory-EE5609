# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA
# Equation of the circle is xTx − 2(a   b)x = 0
# Assuming a=1 and b = 1.
a=1
b=1
O = np.array(([a,b])) # 
P = np.array(([2*a,0])) # passing through Point 1
Q = np.array(([0,2*a])) # passing through Point 2
R= np.array(([a+b,a+b])) # # passing through Point 3 
f = 0  # from eq we get 
r = np.sqrt(LA.norm(O)**2-f)

# function to generate circle
def circ_gen(O,r):
	len = 50
	theta = np.linspace(0,2*np.pi,len)
	x_circ = np.zeros((2,len))
	x_circ[0,:] = r*np.cos(theta)
	x_circ[1,:] = r*np.sin(theta)
	x_circ = (x_circ.T + O).T
	return x_circ

##Generating the circle
x_circ= circ_gen(O,r)
plt.plot(x_circ[0,:],x_circ[1,:],label='$circle $')

tri_coords = np.vstack((P,Q,R,O)).T
plt.scatter(tri_coords[0,:], tri_coords[1,:])
vert_labels = ['P(2a,0)','Q(0,2b)','R(a+b,a+b)','O']
for i, txt in enumerate(vert_labels):
    plt.annotate(txt, # this is the text
                 (tri_coords[0,i], tri_coords[1,i]), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc='best')
plt.title('value of a =1 & b=1')
plt.grid() 
plt.axis('equal')
plt.show()
